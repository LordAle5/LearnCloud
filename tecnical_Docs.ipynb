# %% [markdown]
# <a href="https://colab.research.google.com/github/LordAle5/LearnCloud/blob/main/tecnical_Docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  return "hi"

hello()
# Out:
# 'hi'

# %% [markdown]
# ### Ingest

# %% [markdown]
# ## Modeling

# %%
dsdasdasda
